# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Health Insurance Data)
#
# The dataset contains information about 1300 individuals regarding insurance charges. The data contains an individual's basic information like age, sex, bmi, the region of residence and so on.
#
# Attribute Information:
#
# **age**: Age of the individual
#
# **gender**: Gender of the individual
#
# **bmi**: Body mass index of the individual
#
# **bp**: Systolic blood pressure in mm/hg
#
# **children**: Number of children of the individual
#
# **smoker**: Individual is smoker or not
#
# **region**: Individual's region of residence
#
# **medical_cost**: Individual's medical costs billed by the insurance company

# %% [markdown]
# ##  Table of Content
#
# 1. **[Univariate Analysis](#uni)**
# 2. **[Multivariate Analysis](#multi)**
# 3. **[Handle Non-Numeric Data](#cat)**
# 4. **[Normalization](#norm)**
# 5. **[Transformation Techniques](#trans)**

# %% [markdown]
# **Import the required libraries**

# %%
# import your code here
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load the health insurance dataset and check the first five observations

# %%
# import your code here
insurance_df=pd.read_csv('health_insurance.csv')

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="uni"> </a>
# ## 1. Univariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Are there any extreme observations present in 'bmi'? Support your answer with a plot
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.boxplot(insurance_df['bmi'])
plt.title('Box plot of BMI')
# Out:
# Text(0.5, 1.0, 'Box plot of BMI')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Is the variable 'age' skewed? Support your answer with a plot and metric</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.kdeplot(insurance_df['age'])
plt.show()

# %%
insurance_df['age'].skew()
# Out:
# 0.04359793424360781

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. What is the probability that the individuals have charged less than 25k for medical treatment? Support your answer with the plot</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.distplot(insurance_df['medical_cost'],hist_kws=dict(cumulative=True))
# Out:
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>

# %%
#nearly 83%

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Draw the line for mean and median on the distribution plot and identify the type of skewness for BMI</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
plt.hist(insurance_df['bmi'])
plt.axvline(insurance_df['bmi'].mean(),color='red')
plt.axvline(insurance_df['bmi'].median(),color='black')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Visualize the distribution of medical cost using violin plot and describe its distribution</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.violinplot(insurance_df['medical_cost'])
# Out:
# <AxesSubplot:xlabel='medical_cost'>

# %% [markdown]
# <a id="multi"> </a>
# ## 2. Multivariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there any individual with age less than 30 and meadical cost greater than 40k?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
insurance_df[(insurance_df['age']<30)&(insurance_df['medical_cost']>40000)]
# Out:
#       age gender    bmi  bp   children     region  smoker  medical_cost
# 254    26      F  47.54  156         2  northeast  smoker    42112.2356
# 1009   25      F  55.58  152         1  northeast  smoker    44501.3982
# 1086   26      M  41.75  152         1  northeast  smoker    40904.1995

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Does the scatter plot of BMI and medical cost reveal potential outliers?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.scatterplot(x='medical_cost',y='bmi',data=insurance_df)
# Out:
# <AxesSubplot:xlabel='medical_cost', ylabel='bmi'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Determine the percentage variation in BMI for males and females
#
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
mu=insurance_df.groupby(['gender'])['bmi'].mean()

# %%
sigma=insurance_df.groupby(['gender'])['bmi'].std()

# %%
CV=sigma/np.abs(mu)*100
CV
# Out:
# gender
# F    20.120029
# M    20.118324
# Name: bmi, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Which region has the highest number of males?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
pd.crosstab(insurance_df['region'],insurance_df['gender']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='region'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Analyze the pairwise relationship between the numeric variables
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.pairplot(insurance_df)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Are the medical costs affected by an individual's smoking habits?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
insurance_df.dtypes
# Out:
# age               int64
# gender           object
# bmi             float64
# bp                int64
# children          int64
# region           object
# smoker           object
# medical_cost    float64
# dtype: object

# %%
sns.boxplot(insurance_df['smoker'],insurance_df['medical_cost'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='medical_cost'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Check if the region of residence and age of the individuals have an impact on the medical cost? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
plt.figure(figsize=(10,6))
sns.scatterplot('age','medical_cost',data=insurance_df,hue='region')
# Out:
# <AxesSubplot:xlabel='age', ylabel='medical_cost'>

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Handle Non-Numeric Data

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Create a dummy variable for each category in 'region'
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
insurance_df['region'].value_counts()
# Out:
# southeast    356
# northwest    315
# northeast    315
# southwest    314
# Name: region, dtype: int64

# %%
pd.get_dummies(insurance_df['region'],drop_first=True).head()
# Out:
#    northwest  southeast  southwest
# 0          0          0          1
# 1          0          1          0
# 2          0          1          0
# 3          1          0          0
# 4          1          0          0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Create a variable 'smoker_label' containing unique label for each category in the variable 'smoker'
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
insurance_df['smoker_label']=LE.fit_transform(insurance_df['smoker'])

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Create a variable which will contain the frequency of an individual's gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
insurance_df['gender'].value_counts(normalize=True)
# Out:
# F    0.505385
# M    0.494615
# Name: gender, dtype: float64

# %%
insurance_df['fq_gender']=insurance_df['gender'].map(insurance_df['gender'].value_counts(normalize=True))

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  fq_gender
# 0             1   0.494615
# 1             0   0.505385
# 2             0   0.505385
# 3             0   0.505385
# 4             0   0.505385

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Create a variable such that the value '1' indicates that the individual is a smoker and '0' indicates a non-smoker</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
pd.get_dummies(insurance_df['smoker'],drop_first=True).head()
# Out:
#    smoker
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# <a id="norm"> </a>
# ## 4. Normalization

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Transform BMI such that it will have mean zero and variance one</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
insurance_df['Z_score']=ss.fit_transform(insurance_df[['bmi']])

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  fq_gender   Z_score
# 0             1   0.494615  0.050142
# 1             0   0.505385  0.816583
# 2             0   0.505385  0.538020
# 3             0   0.505385 -1.239588
# 4             0   0.505385 -0.582526

# %%
insurance_df['Z_score'].mean()
# Out:
# -5.143535170431662e-16

# %%
insurance_df['Z_score'].var()
# Out:
# 1.0007698229407238

# %%
sns.distplot(insurance_df['bmi'])
plt.show()
sns.distplot(insurance_df['Z_score'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Check the range of 'age' and transform the values such that the range will be 1</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
from sklearn.preprocessing import MinMaxScaler

# %%
MM = MinMaxScaler()

# %%
insurance_df['age_minmax']=MM.fit_transform(insurance_df[['age']])

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  fq_gender   Z_score  age_minmax
# 0             1   0.494615  0.050142        0.08
# 1             0   0.505385  0.816583        0.02
# 2             0   0.505385  0.538020        0.28
# 3             0   0.505385 -1.239588        0.36
# 4             0   0.505385 -0.582526        0.34

# %%
insurance_df['age_minmax'].mean()
# Out:
# 0.4656153846153852

# %%
insurance_df['age_minmax'].max()
# Out:
# 1.0

# %% [markdown]
# <a id="trans"> </a>
# ## 5. Transformation Techniques

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Check the skewness for 'medical_cost'. If the data is skewed, then use the appropriate technique to reduce the skewness in the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
insurance_df['log_medical_cost']=np.log(insurance_df['medical_cost'])

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  fq_gender   Z_score  age_minmax  log_medical_cost
# 0             1   0.494615  0.050142        0.08          9.734176
# 1             0   0.505385  0.816583        0.02          7.453302
# 2             0   0.505385  0.538020        0.28          8.400538
# 3             0   0.505385 -1.239588        0.36          9.998092
# 4             0   0.505385 -0.582526        0.34          8.260197

# %%
sns.kdeplot(insurance_df['medical_cost'])
plt.show()
sns.kdeplot(insurance_df['log_medical_cost'])
plt.show()

# %%
print('The skewness of original variable',insurance_df['medical_cost'].skew())
print('The skewness of transform variable',insurance_df['log_medical_cost'].skew())
# Out:
# The skewness of original variable 1.5341854555059413
# The skewness of transform variable -0.09331493541417475

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Transform the 'log_medical_cost' values to the original scale and compare the 'medical_cost' and the transformed data</b>
#                 </font>
#             </div>
#
# </td>
#     </tr>
# </table>

# %%
# import your code here
insurance_df['original_medical_cost']=np.exp(insurance_df['log_medical_cost'])

# %%
insurance_df.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  fq_gender   Z_score  age_minmax  log_medical_cost  \
# 0             1   0.494615  0.050142        0.08          9.734176
# 1             0   0.505385  0.816583        0.02          7.453302
# 2             0   0.505385  0.538020        0.28          8.400538
# 3             0   0.505385 -1.239588        0.36          9.998092
# 4             0   0.505385 -0.582526        0.34          8.260197
#
#    original_medical_cost
# 0            16884.92400
# 1             1725.55230
# 2             4449.46200
# 3            21984.47061
# 4             3866.85520

# %%
sns.kdeplot(insurance_df['medical_cost'])
plt.show()
sns.kdeplot(insurance_df['log_medical_cost'])
plt.show()
sns.kdeplot(insurance_df['original_medical_cost'])
plt.show()

# %%
print('The skewness of original variable',insurance_df['medical_cost'].skew())
print('The skewness of transform variable',insurance_df['log_medical_cost'].skew())
print('The skewness after return original variable',insurance_df['original_medical_cost'].skew())
# Out:
# The skewness of original variable 1.5341854555059413
# The skewness of transform variable -0.09331493541417475
# The skewness after return original variable 1.5341854555059415
