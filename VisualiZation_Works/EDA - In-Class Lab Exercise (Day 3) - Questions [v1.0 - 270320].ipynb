# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here
adult_df=pd.read_csv('adult.csv')

# %%
adult_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x='hours.per.week',y='age',data=adult_df)
# Out:
# <AxesSubplot:xlabel='hours.per.week', ylabel='age'>

# %%
#there are no effects of a person's age on the working hours

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(10,8))
sns.lineplot(data=adult_df,x='education.num',y='capital.gain')
# Out:
# <AxesSubplot:xlabel='education.num', ylabel='capital.gain'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(adult_df['hours.per.week'],adult_df['capital.gain'])
# Out:
# <AxesSubplot:xlabel='hours.per.week', ylabel='capital.gain'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(10,6))
sns.lineplot(data=adult_df,x='age',y='hours.per.week')
# Out:
# <AxesSubplot:xlabel='age', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=adult_df,x='age',y='capital.loss')
# Out:
# <AxesSubplot:xlabel='age', ylabel='capital.loss'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(adult_df['capital.gain'],adult_df['age'])
# Out:
# <AxesSubplot:xlabel='capital.gain', ylabel='age'>

# %%
#There is no relation between capital.gain and age

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(10,8))
sns.boxplot(adult_df['income'],adult_df['age'])
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(10,6))
sns.violinplot(data=adult_df,x='sex',y='hours.per.week')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['income'],adult_df['education'])
# Out:
# education  10th  11th  12th  1st-4th  5th-6th  7th-8th  9th  Assoc-acdm  \
# income
# <=50K       871  1115   400      162      317      606  487         802
# >50K         62    60    33        6       16       40   27         265
#
# education  Assoc-voc  Bachelors  Doctorate  HS-grad  Masters  Preschool  \
# income
# <=50K           1021       3134        107     8826      764         51
# >50K             361       2221        306     1675      959          0
#
# education  Prof-school  Some-college
# income
# <=50K              153          5904
# >50K               423          1387

# %%
sns.catplot(x='income',y='education',data=adult_df,col='income')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(8,6))
sns.barplot(x='sex',y='age',data=adult_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(8,6))
sns.violinplot(data=adult_df,x='income',y='hours.per.week')
# Out:
# <AxesSubplot:xlabel='income', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(12,8))
sns.violinplot(data=adult_df,x='race',y='age',hue='sex',split='sex')
# Out:
# <AxesSubplot:xlabel='race', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(12,8))
sns.boxplot(adult_df['workclass'],adult_df['hours.per.week'])
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
adult_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
# type your code here
plt.figure(figsize=(12,8))
sns.boxplot(adult_df['sex'],adult_df['fnlwgt'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fnlwgt'>

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['income'],adult_df['sex']).apply(lambda r:r/r.sum()*100,axis=1)
# Out:
# sex        Female       Male
# income
# <=50K   38.802589  61.197411
# >50K    15.036347  84.963653

# %%
pd.crosstab(adult_df['income'],adult_df['sex']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='income'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['income'],adult_df['race']).apply(lambda r:r/r.sum()*100,axis=1)
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander      Black     Other      White
# income
# <=50K             1.112460            3.086570  11.072006  0.995146  83.733819
# >50K              0.459125            3.519959   4.935595  0.318837  90.766484

# %%
plt.figure(figsize=(12,8))
pd.crosstab(adult_df['income'],adult_df['race']).apply(lambda r:r/r.sum()*100,axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='income'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['occupation'],adult_df['sex'])
# Out:
# sex                Female  Male
# occupation
# ?                     841  1002
# Adm-clerical         2537  1233
# Armed-Forces            0     9
# Craft-repair          222  3877
# Exec-managerial      1159  2907
# Farming-fishing        65   929
# Handlers-cleaners     164  1206
# Machine-op-inspct     550  1452
# Other-service        1800  1495
# Priv-house-serv       141     8
# Prof-specialty       1515  2625
# Protective-serv        76   573
# Sales                1263  2387
# Tech-support          348   580
# Transport-moving       90  1507

# %%
pd.crosstab(adult_df['occupation'],adult_df['sex']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='occupation'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['workclass'],adult_df['income']).apply(lambda r:r/r.sum()*100,axis=1)
# Out:
# income                 <=50K       >50K
# workclass
# ?                  89.596950  10.403050
# Federal-gov        61.354167  38.645833
# Local-gov          70.520784  29.479216
# Never-worked      100.000000   0.000000
# Private            78.132711  21.867289
# Self-emp-inc       44.265233  55.734767
# Self-emp-not-inc   71.507281  28.492719
# State-gov          72.804314  27.195686
# Without-pay       100.000000   0.000000

# %%
pd.crosstab(adult_df['workclass'],adult_df['income']).apply(lambda r:r/r.sum()*100,axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='workclass'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['income'],adult_df['marital.status']).apply(lambda r:r/r.sum()*100,axis=1)
# Out:
# marital.status   Divorced  Married-AF-spouse  Married-civ-spouse  \
# income
# <=50K           16.100324           0.052589           33.511327
# >50K             5.904859           0.127535           85.346257
#
# marital.status  Married-spouse-absent  Never-married  Separated   Widowed
# income
# <=50K                        1.553398      41.229773   3.879450  3.673139
# >50K                         0.433618       6.261956   0.841729  1.084045

# %%
plt.figure(figsize=(12,18))
pd.crosstab(adult_df['income'],adult_df['marital.status']).apply(lambda r:r/r.sum()*100,axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='income'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(adult_df['income'],adult_df['occupation'])
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# income
# <=50K       1652          3263             8          3170             2098
# >50K         191           507             1           929             1968
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# income
# <=50K                   879               1284               1752
# >50K                    115                 86                250
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# income
# <=50K                3158              148            2281              438
# >50K                  137                1            1859              211
#
# occupation  Sales  Tech-support  Transport-moving
# income
# <=50K        2667           645              1277
# >50K          983           283               320
