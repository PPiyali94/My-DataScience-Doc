# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Inclass - Lab<br> (Day 2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
# 1. **[Data Structures with Examples](#Data_Structures)**
# 2. **[Create and Manipulate the DataFrames](#create_manipulate)**
# 3. **[Sort](#sorting)**
# 4. **[Rank](#ranking)**

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Data_Structures'></a>
# ## 1. Data Structures with Examples:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Write a program to create a dataframe from list of lists
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below nested list:**<br>
#
#         data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
data=[['Joy', 21], ['Mia', 15], ['Sam', 14]]

#creating Data Frame
pd.DataFrame(data,columns=['Name','Age'])
# Out:
#   Name  Age
# 0  Joy   21
# 1  Mia   15
# 2  Sam   14

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Extract the second word from the given string
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below string:**<br>
#
#     sentence = 'Be confident and be yourself'

# %%
sentence ='Be confident and be yourself'
sentence[3:12]
# Out:
# 'confident'

# %% [markdown]
# <a id='create_manipulate'></a>
# ## 2. Create and Manipulate the DataFrames:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Split the 'Name' column into two separate columns as First_Name and Last_Name </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>3200</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>4500</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>3600</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>5596</td>
# </tr>
#
# </table>

# %%
#Create data frame
abc={'Name':['Emma Latter','MisJunior ','Sophia Deep','James Smith'],'Salary':[3200,4500,3600,5596]}


df_employees = pd.DataFrame(abc)
df_employees
# Out:
#           Name  Salary
# 0  Emma Latter    3200
# 1   MisJunior     4500
# 2  Sophia Deep    3600
# 3  James Smith    5596

# %%
#splitting Name as First Name and Last Name
df_employees[['First_Name','Last_Name']]=df_employees.Name.str.split(expand=True)
df_employees
# Out:
#           Name  Salary First_Name Last_Name
# 0  Emma Latter    3200       Emma    Latter
# 1   MisJunior     4500  MisJunior      None
# 2  Sophia Deep    3600     Sophia      Deep
# 3  James Smith    5596      James     Smith

# %%
#Drop the Name column
df_employees.drop('Name',axis=1)
# Out:
#    Salary First_Name Last_Name
# 0    3200       Emma    Latter
# 1    4500  MisJunior      None
# 2    3600     Sophia      Deep
# 3    5596      James     Smith

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Select the rows from below dataframe where marks are less than 60 </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Marks</th>
# </tr>
# <tr>
# <td>John</td>
# <td>90</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>50</td>
# </tr>
# <tr>
# <td>Jonny</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>55</td>
# </tr>
#
# </table>

# %%
#create students data frame
data1 = {'Name':['John','Robert','Jonny','Mia'],'Marks':[90,50,89,55]}
students=pd.DataFrame(data1)
students
# Out:
#      Name  Marks
# 0    John     90
# 1  Robert     50
# 2   Jonny     89
# 3     Mia     55

# %%
#finding marks less than 60
students[students['Marks']<60]
# Out:
#      Name  Marks
# 1  Robert     50
# 3     Mia     55

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Write a program to select the rows where the sales are higher than 60000 for Mumbai </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
#create store_sales data frame
data2={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
store_sales=pd.DataFrame(data2)
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
#finding the location 'Mumbai' and Sales >60000 in mumbai
final=store_sales[(store_sales['Location']=='Mumbai') & (store_sales['Sales']>60000)]
final
# Out:
#   Store Location  Sales
# 3     C   Mumbai  90000
# 8     C   Mumbai  89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Write a program to select stores located in Hyderabad</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
data2={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
store_sales=pd.DataFrame(data2)
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
#finding the store location 'Hyderabad'
result=store_sales[store_sales['Location']=='Hyderabad']['Store']
result
# Out:
# 2    A
# 6    D
# Name: Store, dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Write a program to replace the 'Store' column with the values A, B, C, and D with Store_A,  Store_B, Store_C and Store_D respectively </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
data2={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
store_sales=pd.DataFrame(data2)
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
store_sales['Store']=store_sales['Store'].map({'A':'Store_A','B':'Store_B','C':'Store_C','D':'Store_D'})
store_sales
# Out:
#      Store   Location  Sales
# 0  Store_A     Mumbai  40000
# 1  Store_B       Pune  45000
# 2  Store_A  Hyderabad  50000
# 3  Store_C     Mumbai  90000
# 4  Store_D       Pune  89000
# 5  Store_A      Delhi  87000
# 6  Store_D  Hyderabad  85000
# 7  Store_A       Pune  78000
# 8  Store_C     Mumbai  89000
# 9  Store_B       Pune  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Create a dataframe in pandas using the given list.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list**
#
#         city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
#creating data frame 
data={'City':['Delhi','Mumbai','Channai','Kolkata']}
DF=pd.DataFrame(data)
DF
# Out:
#       City
# 0    Delhi
# 1   Mumbai
# 2  Channai
# 3  Kolkata

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Save a given dataframe to a csv file
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
store_sales.to_csv('qw.csv')
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the maximum sales for each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
new_data={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
store_sales=pd.DataFrame(new_data)
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
#finding the maximum sales of each store
pd.pivot_table(store_sales,index=['Store'],values=['Sales'],aggfunc=np.max)
# Out:
#        Sales
# Store
# A      87000
# B      70000
# C      90000
# D      89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Write a program to select all columns, except the 'Location' from the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
store_sales[['Store','Sales']]
# Out:
#   Store  Sales
# 0     A  40000
# 1     B  45000
# 2     A  50000
# 3     C  90000
# 4     D  89000
# 5     A  87000
# 6     D  85000
# 7     A  78000
# 8     C  89000
# 9     B  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Write a program to insert a given column at the second position in a dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
#
# </table>
#
# **Add the variable 'Salary' as second column**<br>
#
#             Salary = [35000, 24000, 55000, 40000]

# %%
#create data frame
stu_data={'Name':['Emma Larter','Mia Junior','Sophia Depp','James Smith'],'Age':[34,59,32,40]}
students_df=pd.DataFrame(stu_data)
students_df
# Out:
#           Name  Age
# 0  Emma Larter   34
# 1   Mia Junior   59
# 2  Sophia Depp   32
# 3  James Smith   40

# %%
Salary = [35000, 24000, 55000, 40000]

# %%
index=1

# %%
students_df.insert(loc=1,column='Salary',value=[35000, 24000, 55000, 40000])
students_df
# Out:
#           Name  Salary  Age
# 0  Emma Larter   35000   34
# 1   Mia Junior   24000   59
# 2  Sophia Depp   55000   32
# 3  James Smith   40000   40

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Write a program to get the third observation of the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
# </table>

# %%
data2={'Name':['Emma Larter','Mia Junior','Sophia Depp','James Smith'],'Age':[34,59,32,40]}
data_df=pd.DataFrame(data2)
data_df
# Out:
#           Name  Age
# 0  Emma Larter   34
# 1   Mia Junior   59
# 2  Sophia Depp   32
# 3  James Smith   40

# %%
data_df.loc[2]
# Out:
# Name    Sophia Depp
# Age              32
# Name: 2, dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Write a program to create a dataframe from the provided lists</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the following lists to create your arrays:**
#
#             columns = ["Science", "Maths", "English"]
#
#             marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
#
# **Hint:** Convert the list marks into an array

# %%
columns = ["Science", "Maths", "English"]

marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
pd.DataFrame(marks,columns=columns,index=['Piyu','Ria','Ani'])
# Out:
#       Science  Maths  English
# Piyu       55     78       88
# Ria        93     63       83
# Ani        94     74       64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Write a program to count total sales per store </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
pd.pivot_table(store_sales,index=['Store'],values=['Sales'],aggfunc=np.sum)
# Out:
#         Sales
# Store
# A      255000
# B      115000
# C      179000
# D      174000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Write a program to count the top five commonly used words in a list
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list:**<br>
#
#             words_list = ['words', 'will', 'where', 'shall', 'we', 'will', 'shall', 'we', 'words', 'where', 'shall',
#                         'will', 'there', 'wow', 'should', 'shall', 'we', 'where', 'should', 'where', 'will',
#                         'there', 'now', 'where', 'we', 'will', 'where', 'should', 'will', 'where']

# %%
words_list = ['words', 'will', 'where', 'shall', 'we', 'will', 'shall', 'we', 'words', 'where', 'shall',
                    'will', 'there', 'wow', 'should', 'shall', 'we', 'where', 'should', 'where', 'will', 
                    'there', 'now', 'where', 'we', 'will', 'where', 'should', 'will', 'where']

# %%
from collections import Counter

# %%
word_count=Counter(words_list)

# %%
word_count
# Out:
# Counter({'words': 2,
#          'will': 6,
#          'where': 7,
#          'shall': 4,
#          'we': 4,
#          'there': 2,
#          'wow': 1,
#          'should': 3,
#          'now': 1})

# %%
word_count.most_common(5)
# Out:
# [('where', 7), ('will', 6), ('shall', 4), ('we', 4), ('should', 3)]

# %% [markdown]
# <a id='sorting'></a>
# ## 3. Sort

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Write a program to sort the dataframe by 'Sales' in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
new_data1={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
store_sales1=pd.DataFrame(new_data)
store_sales1
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
store_sales1.sort_values('Sales')
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 9     B       Pune  70000
# 7     A       Pune  78000
# 6     D  Hyderabad  85000
# 5     A      Delhi  87000
# 4     D       Pune  89000
# 8     C     Mumbai  89000
# 3     C     Mumbai  90000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Write a program to sort the dataframe by 'Store' in ascending order and by 'Sales' in descending order simultaneously
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
new_data={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
store_sales=pd.DataFrame(new_data)
store_sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
store_sales.sort_values(['Store','Sales'],ascending=[True,False])
# Out:
#   Store   Location  Sales
# 5     A      Delhi  87000
# 7     A       Pune  78000
# 2     A  Hyderabad  50000
# 0     A     Mumbai  40000
# 9     B       Pune  70000
# 1     B       Pune  45000
# 3     C     Mumbai  90000
# 8     C     Mumbai  89000
# 4     D       Pune  89000
# 6     D  Hyderabad  85000

# %% [markdown]
# <a id='ranking'></a>
# ## 4. Rank

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Create a column 'Rank_sales' which contains the rank of each store based on sales of the product in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
store_sales['Rank_sales']=store_sales['Sales'].rank(method='average',ascending=True)
store_sales
# Out:
#   Store   Location  Sales  Rank_sales
# 0     A     Mumbai  40000         1.0
# 1     B       Pune  45000         2.0
# 2     A  Hyderabad  50000         3.0
# 3     C     Mumbai  90000        10.0
# 4     D       Pune  89000         8.5
# 5     A      Delhi  87000         7.0
# 6     D  Hyderabad  85000         6.0
# 7     A       Pune  78000         5.0
# 8     C     Mumbai  89000         8.5
# 9     B       Pune  70000         4.0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Rank the dataframe in descending order of sales by each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
store_sales['Rank_sales_descending']=store_sales['Sales'].rank(method='average',ascending=False)
store_sales
# Out:
#   Store   Location  Sales  Rank_sales  Rank_sales_descending
# 0     A     Mumbai  40000         1.0                   10.0
# 1     B       Pune  45000         2.0                    9.0
# 2     A  Hyderabad  50000         3.0                    8.0
# 3     C     Mumbai  90000        10.0                    1.0
# 4     D       Pune  89000         8.5                    2.5
# 5     A      Delhi  87000         7.0                    4.0
# 6     D  Hyderabad  85000         6.0                    5.0
# 7     A       Pune  78000         5.0                    6.0
# 8     C     Mumbai  89000         8.5                    2.5
# 9     B       Pune  70000         4.0                    7.0
